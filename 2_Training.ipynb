# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:**
#
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:**
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:**
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:**

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math


## TODO #1: Select appropriate values for the Python variables below.
batch_size = 64         # batch size
vocab_threshold = 3        # minimum word count threshold
vocab_from_file = True    # if True, load existing vocab file
embed_size = 256           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 3             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity
learning_rate = 1e-3

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.

params = list(decoder.parameters()) + list(encoder.parameters()) 

# TODO #4: Define the optimizer.
#optimizer = 
optimizer = torch.optim.Adam(params, lr=learning_rate)
#decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
# Done (t=1.72s)
# creating index...
#   0%|          | 291/414113 [00:00<02:22, 2907.67it/s]
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [00:59<00:00, 6931.71it/s]

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
'''
response = requests.request("GET", 
                            "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
                            headers={"Metadata-Flavor":"Google"})
'''
for epoch in range(1, num_epochs+1):
    print( epoch)
    
    for i_step in range(1, total_step+1):
        print('step', i_step)
        '''
        if time.time() - old_time > 60:
            old_time = time.time()
            requests.request("POST", 
                             "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                             headers={'Authorization': "STAR " + response.text})
        '''
        
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        print(features.shape)
        print(outputs.shape)
        print(captions.shape)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)
            
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./new_models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./new_models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# 1
# step 1
# torch.Size([64, 256])
# torch.Size([64, 15, 9955])
# torch.Size([64, 15])
# Epoch [1/3], Step [1/6471], Loss: 8.4554, Perplexity: 4700.3886step 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-7039299e1270> in <module>
#      35
#      36         # Obtain the batch.
# ---> 37         images, captions = next(iter(data_loader))
#      38
#      39         # Move batch of images and captions to GPU if CUDA is available.
#
# /usr/local/lib/python3.5/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# /usr/local/lib/python3.5/dist-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# ~/imageCap/CVND---Image-Captioning-Project/data_loader.py in __getitem__(self, index)
#     116
#     117             # Convert image to tensor and pre-process using transform
# --> 118             image = Image.open(os.path.join(self.img_folder, path)).convert('RGB')
#     119             image = self.transform(image)
#     120
#
# /usr/local/lib/python3.5/dist-packages/PIL/Image.py in open(fp, mode)
#    2616         exclusive_fp = True
#    2617
# -> 2618     prefix = fp.read(16)
#    2619
#    2620     preinit()
#
# KeyboardInterrupt:

# %%
torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
encoder.load_state_dict(torch.load(os.path.join('./models', "encoder-1.pkl")))
decoder.load_state_dict(torch.load(os.path.join('./models', "decoder-1.pkl")))
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %%
batch_size = 64         # batch size
vocab_threshold = 3        # minimum word count threshold
vocab_from_file = True    # if True, load existing vocab file
embed_size = 256           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 3             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity
learning_rate = 1e-3

# %%
# (Optional) TODO: Validate your model.
from data_loader_val import get_loader
from collections import defaultdict
import json
import os

def clean_sentence(output):
    sentence = ''
    for i in output:
        word = data_loader.dataset.vocab.idx2word[i]
        if i == 0:
            continue
        if i == 1:
            break
        if i == 18:
            sentence = sentence + word
        else:
            sentence = sentence + ' ' + word
    return sentence

transform_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))
])

#-#-#-# Do NOT modify the code below this line. #-#-#-#

# Create the data loader.
data_loader = get_loader(transform=transform_test,    
                         mode='valid')

vocab_size = len(data_loader.dataset.vocab)
embed_size = 256           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
encoder_file = 'encoder-1.pkl' 
decoder_file = 'decoder-1.pkl'



# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Load the trained weights.
encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))

encoder.eval()
decoder.eval()


pred_result = defaultdict(list)
for img_id, img in data_loader:
    img = img.to(device)
    with torch.no_grad():
        features = encoder(img).unsqueeze(1)
        output = decoder.sample(features)    
    sentence = clean_sentence(output)
    pred_result[img_id.item()].append(sentence)
    
with open('/opt/cocoapi/annotations/captions_val2014.json', 'r') as f:
    caption = json.load(f)
    valid_annot = caption['annotations']
valid_result = defaultdict(list)
for i in valid_annot:
    valid_result[i['image_id']].append(i['caption'])
# Out:
# Vocabulary successfully loaded from vocab.pkl file!

# %%
pred_result
# Out:
# defaultdict(list,
#             {262148: [' a man riding a skateboard down a street .'],
#              393225: [' a bowl of soup and a bowl of soup .'],
#              393226: [' a city bus is parked on the side of the street .'],
#              240301: [' a cow standing in a fenced in area .'],
#              262161: [' a motorcycle parked on a street in front of a building .'],
#              262162: [' a living room with a couch and a couch'],
#              393243: [' a man is eating a donut in a room .'],
#              262175: [' a man wearing a red shirt and a black hat'],
#              131108: [' a black and white photo of a city street .'],
#              393254: [' a truck is parked in a parking lot .'],
#              393258: [' a bed with a laptop and a bag of luggage'],
#              131115: [' a baseball player is swinging at a pitch .'],
#              262189: [' a close up of a street sign on a street'],
#              393266: [' a fire hydrant is on the sidewalk outside of a building .'],
#              393267: [' a group of people sitting at a table with a laptop .'],
#              262197: [' a city street with a clock tower in the background .'],
#              393271: [' a man riding a snowboard down a snow covered slope .'],
#              262200: [' a group of children sitting at a table with a cake on it .'],
#              393274: [' a train is parked on the tracks near a station .'],
#              131131: [' a cat is sitting on a laptop computer .'],
#              393277: [" a clock tower with a clock on it 's side ."],
#              393282: [' a giraffe standing in the middle of a field .'],
#              393284: [' a person on a snowboard in the snow .'],
#              393288: [' a large clock tower with a clock on it .'],
#              524361: [' a bird is perched on a branch in the water .'],
#              74: [' a dog is sitting on a bike parked in front of a building .'],
#              131152: [' a man riding a wave on top of a surfboard .'],
#              262227: [' a laptop computer sitting on top of a desk .'],
#              262228: [' a bike parked on the side of a road .'],
#              524373: [' a giraffe standing in the middle of a forest .'],
#              131159: [' a teddy bear sitting on a wooden bench .'],
#              262235: [' a woman is holding a cell phone in her hand .'],
#              524382: [' a dog sitting on a bench in front of a house .'],
#              262242: [' a man is playing tennis on a tennis court .'],
#              524387: [' a piece of cake on a plate with a fork .'],
#              131089: [' a man is throwing a frisbee in the air .'],
#              524392: [' a kitchen with a stove and a sink'],
#              262262: [' a clock tower with a clock on top of it .'],
#              393338: [' a vase with a flower on it on a table'],
#              262274: [' a person on a surfboard in the water'],
#              131203: [' a laptop computer sitting on top of a desk .'],
#              133: [' a wooden table with a wooden table and a table'],
#              131207: [' a bird is sitting on a bench in the water .'],
#              136: [' a giraffe is standing in the middle of a street .'],
#              139: [' a living room with a couch and a television .'],
#              262284: [' a bathroom with a sink and a mirror'],
#              143: [' a bird is perched on a branch of a tree .'],
#              371395: [' a man sitting on a bench next to a tree .'],
#              524436: [' a man is sitting on a bench with his skateboard .'],
#              393372: [' a woman wearing a tie and a white shirt .'],
#              524450: [' a large bus is parked in front of a building .'],
#              164: [' a kitchen with a refrigerator and a sink .'],
#              524456: [' a woman is sitting on a laptop computer .'],
#              524459: [' a man is sitting on a laptop computer .'],
#              43720: [' a young boy is eating a banana in the grass .'],
#              262323: [' a giraffe is standing in the grass near a tree .'],
#              262325: [' a plate of food with broccoli and meat .'],
#              262334: [' a woman is holding a black and white cat .'],
#              192: [' a baseball player is swinging at a pitch .'],
#              393410: [' a plane flying through the air over a field .'],
#              393411: [' a red and white bus parked in front of a building .'],
#              196: [' a table topped with plates of food and drinks .'],
#              131273: [' a dog is sitting on a car looking out the window .'],
#              262347: [' a bench on a path in the middle of a forest .'],
#              131276: [' a man in a kitchen preparing food on a table .'],
#              393421: [' a living room with a couch and a coffee table'],
#              393423: [' a giraffe standing in the middle of a field .'],
#              131280: [' a baseball player is getting ready to hit a ball .'],
#              262353: [' a group of people sitting around a table with a cake .'],
#              131282: [' a person is preparing food in a kitchen .'],
#              524502: [' a woman is standing in the grass with a kite .'],
#              262360: [' a vase of flowers sitting on a table .'],
#              524507: [' a woman walking down a street holding an umbrella .'],
#              131295: [' a train is traveling down the tracks near a forest .'],
#              262371: [' a cat sitting on top of a suitcase next to a laptop .'],
#              262376: [' a table topped with a vase of flowers and a glass of wine .'],
#              241: [' a group of people sitting on a couch playing a game .'],
#              262386: [' a toilet with a lid and a sink'],
#              524533: [' a city bus is traveling down the street .'],
#              262391: [' a woman is playing a video game in a room .'],
#              524536: [' a man and a woman are posing for a picture .'],
#              192047: [' a bathroom with a sink , mirror and a mirror .'],
#              262394: [' a motorcycle parked on a street in front of a building .'],
#              262396: [' a cat sitting on top of a wooden table .'],
#              393469: [' a group of people riding skis down a snow covered slope .'],
#              257: [' a group of people walking down a street .'],
#              262404: [' a group of people sitting around a table with food .'],
#              393478: [' a train on a train track with people walking around .'],
#              131335: [' a city street with a clock on the side of the street .'],
#              524333: [' a group of people sitting around a table eating .'],
#              262425: [' a group of people standing on a beach .'],
#              283: [' a glass of wine sitting on top of a table .'],
#              285: [' a brown bear standing on a rock in the woods .'],
#              524575: [' a herd of cattle walking down a dirt road .'],
#              131361: [' a woman sitting at a table with a glass of wine .'],
#              294: [' a woman standing in a kitchen preparing food .'],
#              393511: [' a group of people sitting around a table with plates of food .'],
#              262440: [' a bathroom with a toilet and a sink'],
#              393513: [' a man riding a skateboard down a street .'],
#              131379: [' a piece of cake with a fork and knife on it'],
#              524601: [' a group of people standing in a room .'],
#              131386: [' a large airplane flying through a cloudy sky .'],
#              262460: [' a person is holding a teddy bear in a room .'],
#              131390: [' a group of people standing around a pile of grass .'],
#              262466: [' a vase of flowers sitting on a table .'],
#              524611: [' a train is on a track near a forest .'],
#              262471: [' a stop sign on a street with a sign on it'],
#              328: [' a man and woman sitting on a bench in a park .'],
#              546188: [' a man riding a wave on top of a surfboard .'],
#              393547: [' a cat sitting on top of a wooden table .'],
#              262476: [' a woman is playing a video game in a room .'],
#              524621: [' a giraffe standing in the grass near a tree .'],
#              338: [' a kitchen with a stove and cupboards in it'],
#              524627: [' a group of people sitting at a table with a cake .'],
#              393557: [' a zebra standing in a field next to a tree .'],
#              262487: [' a man is playing tennis on a tennis court .'],
#              131416: [' a sandwich and a glass of wine on a table'],
#              131418: [' a woman walking down a street holding an umbrella .'],
#              21903: [' a man is standing in front of a large elephant .'],
#              524637: [' a toilet with a plunger in the middle of a bathroom .'],
#              524638: [' a man is throwing a frisbee in the air .'],
#              393569: [' a bathroom with a toilet and a sink'],
#              524642: [' a living room with a couch and a couch'],
#              357: [' a person on a skateboard on a ramp .'],
#              359: [' a traffic light with a stop sign on it'],
#              360: [' a man is doing a trick on a snowboard .'],
#              262505: [' a car parked on the side of a road .'],
#              393578: [' a train is parked on the tracks near a bridge .'],
#              262509: [' a group of people are sitting on a bench .'],
#              393583: [' a train crossing a bridge over a city street .'],
#              524656: [' a kitchen with a stove and refrigerator in it .'],
#              436968: [' a motorcycle parked on a sidewalk next to a street .'],
#              262514: [' a living room with a couch and a coffee table'],
#              131444: [' a man wearing a suit and tie standing in front of a tree .'],
#              43753: [' a man holding a banana in his hand .'],
#              524665: [' a man is riding a skateboard down the side of a ramp .'],
#              262522: [' a large clock tower with a sky background'],
#              131453: [' a herd of elephants walking across a dry grass field .'],
#              262531: [' a man riding a skateboard down a street .'],
#              524681: [' a group of people flying kites in the sky .'],
#              395: [' a man with a cell phone walking down a street .'],
#              397: [' a pizza sitting on top of a table next to a glass of wine .'],
#              400: [' a boat is docked in a body of water .'],
#              56752: [' a man riding a motorcycle down a street .'],
#              524694: [' a giraffe standing in the middle of a forest .'],
#              524702: [' a woman is holding a wii remote in her hand .'],
#              415: [' a man is playing tennis on a tennis court .'],
#              546203: [' a man is riding a motorcycle down a street .'],
#              131493: [' a group of people sitting on a bench in the sand .'],
#              131494: [' a man riding a motorcycle down a street .'],
#              131497: [' a dog is holding a frisbee in its mouth .'],
#              428: [' a woman holding a wii remote in her hand .'],
#              393647: [' a bus is parked on the side of the street .'],
#              131504: [' a clock tower with a clock on top of it .'],
#              524725: [' a parking meter with a lot of cars on it'],
#              73: [' a bike parked next to a parked motorcycle .'],
#              262587: [' a man riding a wave on top of a surfboard .'],
#              131516: [' a teddy bear sitting on a bed next to a book .'],
#              262594: [' a man riding a bike next to a bike .'],
#              524742: [' a red and white train passing by a building .'],
#              131527: [' a close up of a bunch of broccoli'],
#              393674: [' a baseball player is swinging at a pitch .'],
#              459: [' a man in a suit and tie standing in front of a tv .'],
#              262605: [' a man is playing a video game in a room .'],
#              262608: [' a plate of food with meat and vegetables .'],
#              262609: [' a city street with a lot of traffic .'],
#              393682: [' a piece of cake on a plate with a fork .'],
#              131539: [' a group of people skiing down a snow covered slope .'],
#              472: [' a small plane flying over a body of water'],
#              262617: [' a pizza sitting on top of a table next to a glass of wine .'],
#              474: [' a young boy is playing frisbee in a field'],
#              393692: [' a laptop computer sitting on top of a desk .'],
#              262626: [' a black cat laying on a bed next to a laptop .'],
#              131556: [' a man riding skis down a snow covered slope .'],
#              131557: [' a pizza sitting on top of a table next to a glass of wine .'],
#              486: [' a kitchen with a stove top oven sitting next to a stove .'],
#              524775: [' a bus is parked on the side of the road .'],
#              488: [' a group of men playing a game of baseball .'],
#              393710: [' a young boy is playing frisbee in the grass .'],
#              262642: [' a man is holding a banana in his mouth .'],
#              502: [' a black bear walking through a forest .'],
#              393720: [' a man is doing a trick on a skateboard .'],
#              262651: [' a boat is docked at a dock in the water .'],
#              131581: [' a red and white bus driving down a street .'],
#              262654: [' a plate of food with vegetables and meat .'],
#              524799: [' a skier is coming down the hill'],
#              262658: [' a man is sitting on a bench in the water .'],
#              109313: [' a man and woman standing in a kitchen preparing food .'],
#              520: [' a group of people standing on a beach .'],
#              131593: [' a man holding a cell phone in his hand .'],
#              131597: [' a man riding a motorcycle down a street .'],
#              393743: [' a woman is playing frisbee in the grass .'],
#              262672: [' a skier is skiing down a snowy hill .'],
#              262677: [' a fire hydrant on a sidewalk next to a street .'],
#              524822: [' a living room with a couch and a television .'],
#              536: [' a woman is holding a tennis racket in her hand .'],
#              262682: [' a kitchen with a stove and a sink'],
#              131611: [' a group of elephants standing in a forest .'],
#              131612: [' a man is riding a horse in the grass .'],
#              262686: [' a man is sitting on a bench in the street .'],
#              544: [' a baseball player is swinging at a pitch .'],
#              131617: [' a woman is holding a wii remote in her hand .'],
#              327771: [' a bed with a blanket on top of it'],
#              393768: [' a large vase with a clock on it'],
#              131627: [' a street sign on a pole on a city street'],
#              524844: [' a man is jumping a skateboard in the air .'],
#              262703: [' a person on a snowboard in the snow .'],
#              393777: [' a man is sitting on a couch with a laptop .'],
#              524850: [' a plane is sitting on the tarmac at an airport .'],
#              564: [' a man is on a tennis court with a racket'],
#              569: [' a skate park with a lot of people on it'],
#              546229: [' a group of people standing on a sidewalk .'],
#              393794: [' a bowl of fruit sitting on a table next to a bowl of fruit .'],
#              393804: [' a sandwich and a pickle on a plate .'],
#              393805: [' a zebra standing in a field with a tree in the background'],
#              590: [' a bathroom with a toilet and a sink'],
#              262736: [' a dog is running on a field with a frisbee .'],
#              393809: [' a man is throwing a frisbee in the air .'],
#              262738: [' a man holding a nintendo wii game controller .'],
#              393811: [' a bird is standing on a rock in the water .'],
#              393814: [' a table topped with plates of food and drinks .'],
#              524887: [' a person riding a motorcycle down a street .'],
#              524889: [' a group of people standing on top of a snow covered bench .'],
#              262746: [' a skier is skiing down a snowy hill .'],
#              262758: [' a cat is laying on a blanket on a table .'],
#              393836: [' a bed with a white comforter and pillows on it'],
#              437010: [' a woman walking down a street with her cell phone .'],
#              393838: [' a bowl of food that is on a table .'],
#              623: [' a teddy bear sitting on a bed with a teddy bear .'],
#              393840: [' a group of people riding horses in a river .'],
#              626: [" a clock tower with a clock on it 's side ."],
#              632: [' a living room with a couch and a couch'],
#              636: [' a toilet with a plunger on top of it .'],
#              393857: [' a dog is laying on a blanket on a couch .'],
#              131714: [' a dog is sitting on a bench in front of a window .'],
#              87489: [' a bus is parked on the side of the street .'],
#              393864: [' a plate of food on a table with a fork and knife .'],
#              131725: [' a plate of food with a fork and knife on it'],
#              262800: [' a large jetliner flying through a blue sky .'],
#              393874: [' a man sitting on a couch holding a laptop .'],
#              661: [' a hot dog with ketchup and mustard on it .'],
#              524954: [' a black and white photo of a bathroom with a toilet .'],
#              524957: [' a man riding a horse in a rodeo .'],
#              131743: [' a man and woman standing in a room with a wii controller .'],
#              524962: [' a man is on a skateboard in the air'],
#              675: [' a black cat is sitting on a wooden table .'],
#              524977: [' a kitchen with a stove top oven sitting next to a stove .'],
#              524979: [' a woman is sitting on a bench with her dog .'],
#              692: [' a baby is sitting on a couch with a toothbrush in it .'],
#              693: [' a boy is doing a trick on a skateboard .'],
#              699: [' a picture of a person holding a pair of scissors .'],
#              524992: [' a red and yellow bus driving down a street .'],
#              711: [' a living room with a couch and a couch .'],
#              393928: [' a group of people on a snow covered hill .'],
#              715: [' a pile of fruit sitting on a table .'],
#              724: [' a stop sign with a red arrow on it'],
#              393942: [' a black and white photo of a train on a train track'],
#              131800: [' a man is holding a sandwich in his hand .'],
#              262873: [' a woman is standing in the snow holding a snowboard .'],
#              730: [' a red double decker bus driving down a street .'],
#              87503: [' a train on a train track with people walking around .'],
#              131804: [' a man riding a motorcycle down a street .'],
#              525021: [' a man riding a motorcycle down a street .'],
#              525024: [' a group of people walking down a street .'],
#              131815: [' a woman holding a banana in her hand .'],
#              262895: [' a man wearing a suit and tie'],
#              262896: [' a plate of food with a fork and knife on it .'],
#              174888: [' a man in a yellow shirt holding a hot dog .'],
#              393971: [' a laptop computer sitting on top of a table .'],
#              262900: [' a giraffe standing in the grass near a tree .'],
#              757: [' a baby elephant standing in the water .'],
#              761: [' a group of people standing on top of snow covered ground .'],
#              525050: [' a street sign on a pole on a street .'],
#              393979: [' a herd of zebra standing on top of a dry grass field .'],
#              764: [' a group of people standing on top of a grass covered field .'],
#              393982: [' a stop sign on a pole on a street .'],
#              393984: [' a man standing in a kitchen with a refrigerator .'],
#              131841: [' a piece of cake on a plate with a fork .'],
#              525058: [' a city street with a clock on the side of the street .'],
#              772: [' a couple of sheep are standing in a field .'],
#              775: [' a bike parked on the side of a road .'],
#              776: [' a teddy bear sitting on a couch next to a book .'],
#              393995: [' a cat sitting on top of a wooden table .'],
#              131856: [' a person flying a kite in the sky .'],
#              785: [' a skier is skiing down a hill .'],
#              394002: [' a bike parked next to a bike rack .'],
#              262275: [' a woman riding a horse on a dirt road .'],
#              262933: [' a man riding a horse in the water .'],
#              394009: [' a bathroom with a toilet and a sink'],
#              262938: [' a teddy bear sitting on a table next to a window .'],
#              525083: [' a kitchen with a stove , sink and refrigerator .'],
#              262940: [' a plane is sitting on the runway at the airport'],
#              131869: [' a man is playing tennis on a tennis court .'],
#              525087: [' a man riding a horse in a rodeo .'],
#              802: [' a kitchen with a stove and refrigerator in it'],
#              810: [' a person is sitting on a table with a laptop .'],
#              371506: [' a close up of a plate of broccoli and a bowl of broccoli'],
#              394033: [' a woman is sitting at a table with a bunch of fruit .'],
#              525106: [' a man wearing a red jacket and goggles skiing down a hill'],
#              131895: [' a group of zebras are standing in a field .'],
#              827: [' a zebra standing in a field with a tree in the background'],
#              525118: [' a table topped with a bunch of bananas .'],
#              831: [' a man riding a skateboard down a street .'],
#              394050: [' a man holding a baseball bat on a field .'],
#              836: [' a snowboarder is jumping in the air on a snowboard .'],
#              262985: [' a group of boats docked in a harbor .'],
#              262986: [' a black bear is sitting on a rock .'],
#              262987: [' a red stop sign sitting on a street corner .'],
#              131919: [' a man riding a bike down a street next to a river .'],
#              131920: [' a table with a cup of coffee and a cup of coffee .'],
#              262993: [' a cow standing in a fenced in area .'],
#              524431: [' a horse is pulling a cart down a street .'],
#              394079: [' a person holding a hot dog on a table'],
#              131938: [' a cat laying on a blanket on a bed'],
#              525155: [' a woman holding a kite in a field .'],
#              263014: [' a group of zebras are standing in a field .'],
#              872: [' a baseball player is swinging at a pitch .'],
#              873: [' a large building with a clock on it'],
#              525162: [' a man is surfing on a wave in the ocean .'],
#              525170: [' a woman sitting at a table with a glass of wine .'],
#              885: [' a man is playing tennis on a tennis court .'],
#              131965: [' a bench on a path in the middle of a forest .'],
#              525183: [' a man is riding a horse in the water .'],
#              525184: [' a woman sitting on a couch with a teddy bear .'],
#              131969: [' a red and white fire hydrant on a city street'],
#              196759: [' a white truck parked on a street next to a building .'],
#              263052: [' a man riding a wave on top of a surfboard .'],
#              525202: [' a pizza sitting on top of a table next to a glass of wine .'],
#              394131: [' a large jetliner sitting on top of an airport tarmac .'],
#              394132: [' a teddy bear sitting on a bed next to a book .'],
#              394133: [' a bed with a blanket on it and a lamp'],
#              525208: [' a city street with a traffic light and a clock tower .'],
#              923: [' a train on a train track with people walking around .'],
#              263068: [' a man is on a skateboard on a ramp .'],
#              263073: [' a snowboarder performing a jump off a ramp .'],
#              525227: [' a young man is doing a trick on a skateboard .'],
#              394157: [' a clock on a pole with a clock on it'],
#              132024: [' a skier is coming down the hill'],
#              22004: [' a man is skateboarding on a ramp in a skate park .'],
#              482719: [' a banana and a banana are on a table .'],
#              525247: [' a cat is sitting on top of a laptop computer .'],
#              962: [' a man is playing tennis on a tennis court .'],
#              132037: [" a clock tower with a clock on it 's side ."],
#              969: [' a group of people playing frisbee on a field .'],
#              132042: [' a man is sitting on a couch playing a video game .'],
#              974: [' a man is standing in the street with an elephant .'],
#              263120: [' a herd of elephants walking through a field .'],
#              248810: [' a giraffe standing in the middle of a forest .'],
#              394199: [' a man riding a motorcycle down a street .'],
#              525272: [' a pizza sitting on top of a wooden table .'],
#              985: [' a bus parked in front of a building .'],
#              987: [' a stove top oven sitting next to a stove top oven .'],
#              394206: [' a man is riding a motorcycle down a street .'],
#              263136: [' a horse is standing in the grass near a tree .'],
#              132067: [' a bedroom with a bed and a lamp'],
#              525286: [' a clock on a pole on a city street'],
#              999: [' a baseball player is swinging at a pitch .'],
#              1000: [' a group of people standing on a tennis court .'],
#              263146: [' a man riding a motorcycle down a street .'],
#              525297: [' a person holding a cell phone in their hand .'],
#              132084: [' a motorcycle parked on a road next to a tree .'],
#              263163: [' a man sitting on a bench in front of a building .'],
#              394240: [' a bike parked on the side of a road .'],
#              1029: [' a plane flying through the air over a mountain .'],
#              394246: [' a man riding a skateboard down a street .'],
#              87553: [' a woman sitting on a bench in a park .'],
#              263177: [' a city street filled with lots of traffic .'],
#              263178: [' a bowl of fruit sitting on top of a table .'],
#              394251: [' a truck is parked in a parking lot .'],
#              394259: [' a bowl of food with a spoon and fruit'],
#              132116: [' a plate of food with a fork and knife on it'],
#              132121: [' a living room with a couch and a couch'],
#              109992: [' a person on a snowboard on a snowy hill .'],
#              525344: [' a large jetliner sitting on top of an airport tarmac .'],
#              263202: [' a man is holding a cell phone in his hand .'],
#              394275: [' a bus that is parked in front of a building'],
#              132132: [' a man is standing in front of a bunch of bananas .'],
#              415238: [' a fire hydrant with a red flower in it'],
#              1063: [' a giraffe standing in the grass near a tree .'],
#              1064: [' a plate of food with a fork and knife on it'],
#              525354: [' a man wearing a tie and a white shirt .'],
#              263211: [' a giraffe standing in the grass near a tree .'],
#              132143: [' a city street with a traffic light on the side of the road .'],
#              394288: [' a large elephant is standing in the dirt .'],
#              525361: [' a train on a train track with people walking around .'],
#              263223: [' a skier is coming down the slope on a sunny day .'],
#              525369: [' a person laying on a bed with a laptop'],
#              525371: [' a large clock tower with a clock on it .'],
#              525373: [' a young boy is eating a slice of pizza .'],
#              525376: [' a black and white photo of a car with a dog on it'],
#              132161: [' a piece of cake on a plate with a fork .'],
#              525381: [' a baseball player is swinging at a pitch .'],
#              39317: [' a bathroom with a sink and a mirror'],
#              1103: [' a group of people riding horses on a beach .'],
#              394320: [' a group of people sitting around a table with a pizza .'],
#              394322: [' a group of people standing around a table with a dog .'],
#              263251: [' a woman walking down a street holding an umbrella .'],
#              132182: [' a baseball player is swinging at a pitch .'],
#              394328: [' a toilet with a seat on top of it'],
#              263258: [' a baseball player is swinging at a pitch .'],
#              132189: [' a bus that is parked on a street .'],
#              394334: [' a display case with various pastries and pastries .'],
#              263268: [' a toilet with a lid and a sink'],
#              525420: [' a bathroom with a toilet and a sink'],
#              458941: [' a vase of flowers sitting on a table .'],
#              394352: [' a group of people riding horses down a dirt road .'],
#              132210: [' a red and white fire truck parked in a parking lot .'],
#              263288: [' a pair of scissors and a pair of scissors .'],
#              1146: [' a man wearing a suit and tie standing in front of a window .'],
#              132219: [' a man wearing a green shirt and yellow tie .'],
#              263292: [' a clock on a brick wall next to a building .'],
#              1149: [' a group of people standing around a table with a cake on it .'],
#              132223: [' a woman holding a nintendo wii game controller .'],
#              1153: [' a banana and a glass of wine are on a table .'],
#              263299: [' a red train is parked on the tracks .'],
#              87574: [' a clock on a pole with a clock on it .'],
#              1164: [' a large elephant standing on top of a sandy beach .'],
#              1171: [' a large clock on a pole with a sky background'],
#              1176: [' a person on a skateboard on a ramp'],
#              263323: [' a man sitting on a couch in a living room .'],
#              1180: [' a group of people sitting around a table with a cake .'],
#              132272: [' a man is holding a plate of food on a table .'],
#              263346: [' a large airplane sitting on top of an airport tarmac .'],
#              127451: [' a man is skiing down a hill on a snow covered slope .'],
#              1205: [' a room with a bed and a window'],
#              263351: [' a woman is sitting on a bench talking on her cell phone .'],
#              263355: [' a skier is coming down the slope in the snow .'],
#              263359: [' a man riding a horse in a field .'],
#              132288: [' a man is on a skateboard in the air'],
#              394444: [' a man is skateboarding on a skateboard .'],
#              394449: [' a train is parked next to a train station .'],
#              263382: [' a clock is on a wall in a room .'],
#              394458: [' a black and white photo of a baby elephant'],
#              394460: [' a living room with a couch and a table'],
#              132317: [' a laptop computer sitting on top of a table .'],
#              263393: [' a table with plates and bowls of food on it'],
#              525542: [' a bus is parked on the side of the road .'],
#              132328: [' a group of people flying kites in the air .'],
#              132329: [' a bathroom with a sink and a mirror'],
#              525546: [' a woman holding a tennis racquet on a tennis court .'],
#              263403: [' a man is surfing on a wave in the ocean .'],
#              394478: [' a cat sitting on top of a laptop computer .'],
#              301326: [' a cat sitting on top of a wooden table .'],
#              132336: [' a red double decker bus driving down a street .'],
#              8771: [' a person on a snowboard in the snow .'],
#              42: [' a teddy bear sitting on a blanket on a table .'],
#              263412: [' a city street with a traffic light on the side of the road .'],
#              132342: [' a bathroom with a toilet and a sink'],
#              525559: [' a zebra standing in a field next to a tree .'],
#              568191: [' a bird is sitting on a beach next to the ocean .'],
#              525568: [' a zebra standing in a field with trees in the background'],
#              263425: [' a man is standing in the middle of a boat .'],
#              263428: [' a group of people standing around a train .'],
#              132362: [' a table with plates of food and drinks on it .'],
#              1292: [' a woman is sitting on a bench with her cell phone .'],
#              394510: [' a young boy is riding his skateboard down the street .'],
#              1296: [' a woman is holding a cell phone in her hands .'],
#              525587: [' a truck parked in the street next to a building .'],
#              394517: [' a bathroom with a sink and a mirror'],
#              132375: [' a vase with a flower in it on a table'],
#              525600: [' a group of giraffes are standing in a field .'],
#              132389: [' a dog is sitting on a bench in the middle of a field .'],
#              263463: [' a man is standing in the street with a car .'],
#              132393: [' a street sign on a pole on a street .'],
#              327383: [' a red and white bus parked in front of a building .'],
#              525616: [' a group of people playing a game with nintendo wii controllers .'],
#              263474: [' a bathroom with a toilet and a sink'],
#              525619: [' a man is throwing a frisbee in the grass .'],
#              263477: [' a giraffe standing in the middle of a dirt road .'],
#              132408: [' a man riding a horse in a field .'],
#              1340: [' a white toilet sitting next to a white sink .'],
#              1342: [' a microwave is sitting on top of a counter .'],
#              394559: [' a woman is playing tennis on a tennis court .'],
#              1347: [' a laptop computer sitting on top of a desk .'],
#              1353: [' a woman sitting on a couch in a room .'],
#              525646: [' a pizza sitting on top of a table next to a glass of wine .'],
#              174989: [' a woman is sitting on a bench with her cell phone .'],
#              263505: [' a man riding a motorcycle down a street .'],
#              1369: [' a man is on a beach with a surfboard .'],
#              1374: [' a train on a train track with a sky background'],
#              263520: [' a giraffe standing in the grass near a tree .'],
#              525665: [' a group of people riding horses down a snow covered slope .'],
#              525666: [' a group of people on a beach playing with a frisbee .'],
#              525667: [' a group of people standing on a sidewalk .'],
#              8775: [' a bedroom with a bed and a lamp'],
#              394608: [' a man is on a beach with a surfboard .'],
#              1393: [' a cat sitting on a bench in the middle of a room .'],
#              525682: [' a living room with a couch and a tv'],
#              394611: [' a giraffe standing in a field next to a tree .'],
#              1398: [' a black cat is sitting on a bench in the grass .'],
#              1404: [' a teddy bear sitting on a couch with a book .'],
#              525702: [' a woman is holding a cell phone in her hand .'],
#              525705: [' a baseball player is swinging his bat at a ball'],
#              394635: [' a train on a train track with people walking around .'],
#              327917: [' a person flying a kite in the sky .'],
#              1425: [' a white plate topped with a piece of cake .'],
#              132499: [" a clock tower with a clock on it 's side ."],
#              437145: [' a fire hydrant on a street with a tree in the background .'],
#              1436: [' a man sitting on a couch with a laptop .'],
#              132509: [' a picture of a giraffe in the middle of a field .'],
#              132510: [' a skier is coming down the slope on a sunny day .'],
#              263586: [' a woman is playing tennis on a tennis court .'],
#              394659: [' a kitchen with a stove and microwave in it'],
#              263588: [' a couple of birds sitting on top of a sandy beach .'],
#              394663: [' a man is riding an elephant through the jungle .'],
#              1448: [' a giraffe standing in the grass near a tree .'],
#              263594: [' a car parked on the side of a road .'],
#              458323: [' a woman is standing in the street with a skateboard .'],
#              394677: [' a group of people sitting on a couch watching a game .'],
#              1464: [' a man riding skis down a snow covered slope .'],
#              394681: [' a red double decker bus driving down a street .'],
#              263612: [' a dog is sitting on a bench in the grass .'],
#              263613: [' a group of giraffes standing around a wooden structure .'],
#              132544: [' a group of people playing a game of tennis .'],
#              525762: [' a man is playing tennis on a tennis court .'],
#              525763: [' a group of people are rowing boats in a canal .'],
#              132554: [' a woman is riding a horse in a corral .'],
#              524535: [' a table with a knife and fork on a table'],
#              525777: [' a train is parked on the tracks near a station .'],
#              1490: [' a man is surfing on a wave in the ocean .'],
#              394715: [' a laptop computer sitting on top of a desk .'],
#              263644: [' a bedroom with a bed and a lamp'],
#              1503: [' a laptop computer sitting on top of a desk .'],
#              132578: [' a cat laying on a bed next to a laptop .'],
#              394724: [' a man riding a wave on top of a surfboard .'],
#              132587: [' a man is on a skateboard in a skate park'],
#              263664: [' a woman riding a bike down a city street .'],
#              263668: [' a street sign on a pole on a city street'],
#              1525: [' a large white and black train on a train track'],
#              1532: [' a city street with a traffic light on the side of the road .'],
#              109482: [' a bedroom with a bed and a lamp'],
#              263679: [' a person on a beach flying a kite .'],
#              132612: [' a group of animals walking down a dirt road .'],
#              132615: [' a baseball player is swinging at a pitch .'],
#              132622: [' a grizzly bear is standing in the grass .'],
#              263696: [' a woman walking down a street holding an umbrella .'],
#              1554: [' a horse is standing in a field with a dog .'],
#              263700: [' a man riding a motorcycle down a street .'],
#              394773: [' a motorcycle parked on a street next to a tree .'],
#              525849: [' a group of people sitting around a table with wine glasses .'],
#              1563: [' a man in a red jacket and a yellow jacket'],
#              445233: [' a woman is sitting at a table with a plate of food .'],
#              132644: [' a man in a kitchen preparing food on a counter .'],
#              1573: [' a kitchen with a refrigerator and a stove .'],
#              1577: [' a vase with flowers sitting on a table .'],
#              263723: [' a pizza sitting on top of a wooden table .'],
#              132652: [' a woman is sitting on a couch with a cell phone .'],
#              525869: [' a herd of cattle grazing on a dry grass field .'],
#              284253: [' a pile of fruit sitting on a table next to a pile of oranges .'],
#              1584: [' a red double decker bus driving down a street .'],
#              394801: [' a pile of fruit sitting on top of a counter .'],
#              1590: [' a grill with a bunch of food on it'],
#              1591: [' a picture of a car that is parked on a train track .'],
#              525880: [' a man sitting on a bench in the water .'],
#              1599: [' a man is on a tennis court with a racket'],
#              22112: [' a table topped with a bowl of fruit and vegetables .'],
#              22113: [' a fire hydrant on a sidewalk next to a street .'],
#              132682: [' a white toilet sitting next to a white sink .'],
#              525899: [' a man riding a wave on top of a surfboard .'],
#              132686: [' a group of people flying kites in the sky .'],
#              525903: [' a table topped with plates of food and drinks .'],
#              132689: [' a group of people standing around a bench .'],
#              132690: [' a cat laying on top of a blanket on a table .'],
#              525908: [' a man is playing tennis on a tennis court .'],
#              525909: [' a cat sitting on top of a couch next to a laptop .'],
#              394840: [' a man riding a horse down a street .'],
#              394841: [' a bathroom with a toilet and a sink'],
#              1626: [' a man and woman playing a game on a wii .'],
#              132702: [' a close up of a plate of broccoli and meat'],
#              132703: [' a man is doing a trick on a skateboard'],
#              132706: [' a pizza sitting on top of a table next to a glass of wine .'],
#              263780: [' a baby elephant standing in the water .'],
#              22118: [' a beach with people walking around it'],
#              525927: [' a train is on the tracks near a bridge .'],
#              437180: [' a woman is sitting on a couch with a laptop .'],
#              1647: [' a pair of scissors and a pair of scissors .'],
#              263793: [' a man is walking down a path next to a tree .'],
#              263796: [' a dirty bathroom with a toilet and a sink'],
#              1655: [' a man is standing on a hill next to a woman .'],
#              132733: [' a dog is laying on a blanket on a blanket .'],
#              1667: [' a young girl is holding a baby in a pink shirt .'],
#              1668: [' a baseball player is swinging at a pitch .'],
#              1675: [' a black cat sitting on top of a laptop computer .'],
#              394892: [' a man riding a skateboard down a street .'],
#              1682: [' a person on a beach with a sail in the water .'],
#              525971: [' a man riding a motorcycle down a street .'],
#              263828: [' a bike parked next to a parked motorcycle .'],
#              393497: [' a group of people standing around a bench on a sidewalk .'],
#              394904: [' a group of people sitting on a bench in the water .'],
#              263834: [' a man riding a motorcycle down a street .'],
#              394909: [' a person on a beach playing with a frisbee'],
#              525988: [' a teddy bear sitting on a table next to a window .'],
#              132776: [' a man riding on top of a elephant in the water .'],
#              526000: [' a woman wearing a red dress and a white shirt .'],
#              263858: [' a man riding a wave on top of a surfboard .'],
#              526004: [' a little boy is sitting at a table with a cake .'],
#              132791: [' a man is riding a horse in the water .'],
#              263866: [' a train is parked on the tracks near a forest .'],
#              132796: [' a man riding on a motorcycle in a village .'],
#              394941: [' a man is standing on a beach with a kite in the sky .'],
#              526021: [' a man is playing tennis on a tennis court .'],
#              524577: [' a clock on a pole on a city street'],
#              263881: [' a giraffe standing in the middle of a field .'],
#              1739: [' a truck is parked on the side of a road .'],
#              526028: [' a plate of food with a fork and knife'],
#              394957: [' a bathroom with a toilet and a sink'],
#              132814: [' a zebra standing in a field next to a tree .'],
#              526040: [' a skier is coming down the hill on a sunny day .'],
#              526044: [' a horse is standing in the middle of a field .'],
#              1757: [' a woman sitting at a table with a wine glass .'],
#              1761: [' a plane flying over a body of water'],
#              1779: [' a street sign on a pole on a street .'],
#              263929: [' a group of people riding horses down a dirt road .'],
#              132860: [' a table with a variety of items and a pair of scissors .'],
#              132861: [' a clock tower with a sky background'],
#              395006: [' a bench sitting on a wooden bench next to a tree .'],
#              437205: [' a woman holding a hot dog in her hands .'],
#              1799: [' a city bus is traveling down the street .'],
#              526089: [' a man is sitting on a laptop computer .'],
#              1803: [' a bathroom with a toilet and a sink'],
#              275025: [' a horse is standing in the grass near a fence .'],
#              526103: [' an elephant standing in a zoo enclosure .'],
#              263961: [' a train is traveling down the tracks near a forest .'],
#              1818: [' a zebra standing in a field next to a tree .'],
#              263966: [' a dog is sitting on a bench in the water .'],
#              263969: [' a woman is holding a glass of wine .'],
#              132901: [' a man riding a motorcycle down a street .'],
#              395046: [' a train is on the tracks near a station .'],
#              526126: [' a man riding a skateboard down a street .'],
#              240605: [' a table with a laptop and a glass of wine'],
#              1840: [' a group of people standing outside of a building'],
#              1841: [' a woman is holding a cell phone in her hand .'],
#              524595: [' a group of people on a tennis court playing tennis .'],
#              526132: [' a giraffe standing in the middle of a dirt road .'],
#              526133: [' a skier is seen in the snow with a snowboard .'],
#              1852: [' a pair of scissors and a pair of scissors .'],
#              526143: [' a giraffe standing in the middle of a forest .'],
#              1856: [' a man riding a wave on top of a surfboard .'],
#              132931: [' a baseball player is swinging at a pitch .'],
#              395083: [' a group of people flying kites in the sky .'],
#              1869: [' a group of elephants walking in the dirt .'],
#              264017: [' a plate with a sandwich and a glass of wine'],
#              109539: [' a man walking down a street with a umbrella .'],
#              132953: [' a man riding a wave on top of a surfboard .'],
#              264032: [' a kitchen with a refrigerator and a stove'],
#              395113: [' a bus that is parked in a parking lot .'],
#              526186: [' a man in a kitchen preparing food on a counter .'],
#              526188: [' a man flying a kite in the sky .'],
#              1903: [' a hot dog with ketchup and mustard on it .'],
#              395124: [' a bathroom with a toilet and a sink'],
#              526197: [' a display case with various types of doughnuts .'],
#              132982: [' a bus driving down a street next to a building .'],
#              395130: [" a large clock tower with a clock on it 's side ."],
#              132987: [' a man is surfing on a wave in the ocean .'],
#              306154: [' a bench in the water near a river .'],
#              132992: [' a teddy bear sitting on a wooden table .'],
#              133000: [' a train is traveling down the tracks near a bridge .'],
#              133002: [' a man riding a bike down a street .'],
#              526222: [' a woman is playing tennis on a tennis court .'],
#              502766: [' a group of people in a field playing with a frisbee'],
#              306159: [' a bathroom with a toilet and a sink'],
#              1948: [' a man is sitting on a bench with a baby elephant .'],
#              133025: [' a man is standing on a tennis court with a racquet .'],
#              1955: [' a man is throwing a frisbee in the air .'],
#              1960: [' a group of people playing a game of soccer .'],
#              133034: [' a laptop computer sitting on top of a table .'],
#              395180: [' a man riding a horse in the middle of a lake .'],
#              395182: [' a man in a red jacket skiing down a hill .'],
#              526256: [' a clock tower with a clock on top of it .'],
#              395185: [' a street sign that is on a pole .'],
#              133042: [' a baseball player is swinging at a pitch .'],
# ...
#              133343: [' a man wearing a suit and tie .'],
#              526560: [' a zebra standing in a field next to a tree .'],
#              264420: [' a elephant that is standing in the grass .'],
#              264423: [' a man is flying a kite in the sky .'],
#              264424: [' a baseball player is swinging at a pitch .'],
#              395497: [' a group of birds flying over a beach .'],
#              526570: [' a woman walking down a street holding an umbrella .'],
#              526576: [' a man is riding a skateboard down the side of a ramp .'],
#              2290: [' a boat is docked in the water near a lake .'],
#              526580: [' a man is standing in the middle of a room .'],
#              2295: [' a cat sitting on top of a wooden table .'],
#              395512: [' a kitchen with a stove and microwave in it'],
#              264441: [' a cat laying on top of a white blanket .'],
#              395514: [' a group of men sitting on a bench in front of a crowd .'],
#              2299: [' a group of people standing around a tennis court .'],
#              2302: [' a horse is standing in the middle of a field .'],
#              133377: [' a zebra standing in a dirt area next to a tree .'],
#              133380: [' a bird sitting on a branch in the grass .'],
#              264454: [' a red double decker bus driving down a street .'],
#              133386: [' a group of people on a skate board at a skate park'],
#              2315: [' a group of elephants walking across a river .'],
#              264461: [' a toilet and a sink in a bathroom'],
#              387: [' a laptop computer sitting on top of a desk .'],
#              175151: [' a bus driving down a street next to a building .'],
#              526622: [' a bike parked on the side of a road .'],
#              264482: [' a cake with a chocolate frosted cake on it'],
#              284379: [' a man is riding a surfboard in the water .'],
#              133412: [' a pizza with a knife and fork on it'],
#              395557: [' a room with a large window and a window .'],
#              264489: [' a vase with a flower in it on a table'],
#              2346: [' a table with a glass of wine and a glass of wine'],
#              264497: [' a man and woman sitting on a bench in a room .'],
#              526645: [' a giraffe standing in the grass near a tree .'],
#              382345: [' a person flying a kite in the sky .'],
#              395575: [' a boat is docked at a dock in the water .'],
#              264506: [' a person is standing in the snow with a mountain in the background .'],
#              526654: [' a man with a beard and a black shirt and a white shirt'],
#              526675: [' a living room with a couch and a couch'],
#              2388: [' a white toilet sitting next to a white sink .'],
#              395606: [' a young boy holding a baseball bat on a field .'],
#              264535: [' a man sitting on a bench in front of a bench .'],
#              133464: [' a train is on a track near a bridge .'],
#              264540: [' a table topped with plates of food and drinks'],
#              133470: [' a man is on a beach with a surfboard .'],
#              133476: [' a sandwich and a cup of coffee on a table .'],
#              395621: [' a group of people standing around a table with food .'],
#              264554: [' a toilet with a plunger in the middle of a bathroom .'],
#              133485: [' a vase of flowers sitting on a table .'],
#              526704: [' a giraffe standing in the middle of a dirt road .'],
#              395633: [' a boat is docked on a lake next to a river .'],
#              526706: [' a group of cows standing in a field next to a tree .'],
#              526711: [' a large jetliner sitting on top of an airport tarmac .'],
#              264568: [' a woman is preparing food in a kitchen .'],
#              264572: [' a baseball player is swinging at a pitch .'],
#              2431: [' a table with a plate of food and a glass of wine .'],
#              526721: [' a cat sitting on top of a wooden table .'],
#              2434: [' a laptop computer sitting on top of a table .'],
#              526723: [' a woman is sitting on a bench in the snow .'],
#              526728: [' a man is standing in the street with a suitcase .'],
#              133515: [' a kitchen with a stove , sink and refrigerator .'],
#              526732: [' a glass vase with a flower in it'],
#              526737: [' a living room with a couch and a coffee table'],
#              264594: [' a woman is sitting on a horse in a park .'],
#              2453: [' a bench sitting in the middle of a forest .'],
#              264599: [' a city street with a lot of cars and buildings'],
#              526751: [' a boat is docked on the water near a lake .'],
#              133537: [' a train is on the tracks near a platform .'],
#              526756: [' a clock on a pole on a city street'],
#              371782: [' a teddy bear sitting on a wooden table .'],
#              264615: [' a group of horses standing in a field next to a tree .'],
#              65948: [' a kitchen with a table and chairs in it'],
#              526762: [' a group of cows standing in a field next to a tree .'],
#              264619: [' a person flying a kite in the sky .'],
#              2477: [' a woman sitting on a couch with a laptop .'],
#              526767: [' a bathroom with a toilet and a sink'],
#              264625: [' a vase of flowers sitting on a table .'],
#              133556: [' a baseball player is swinging at a pitch .'],
#              395701: [' a living room with a couch and a television .'],
#              133559: [' a group of people on a beach playing with a frisbee .'],
#              526778: [' a skier is coming down the slope on a sunny day .'],
#              2495: [' a toilet with a seat and a pair of shoes on it .'],
#              395714: [' a bowl of fruit sitting on top of a table .'],
#              133571: [' a horse is standing in the middle of a street .'],
#              395717: [' a man is sitting on a boat in the water .'],
#              157206: [' a large pile of luggage sitting on top of a wooden floor .'],
#              395723: [' a zebra standing in a field next to a tree .'],
#              264654: [' a bed with a laptop and a backpack'],
#              526800: [' a baseball player is swinging at a pitch .'],
#              526801: [' a laptop computer sitting on top of a desk .'],
#              264659: [' a white bird sitting on a cement bench .'],
#              526804: [' a table with a pizza on a table'],
#              526806: [' a train on a train track with people walking around .'],
#              2521: [' a sign that is on a pole on a street .'],
#              133596: [' a woman is standing on a beach holding a kite .'],
#              2525: [' a woman standing in front of a store selling fruit .'],
#              262565: [' a baseball player is swinging at a pitch .'],
#              2529: [' a clock tower with a clock on top of it .'],
#              2532: [' a man is skiing down a snowy hill .'],
#              395749: [' a man sitting on a bench in the woods .'],
#              395752: [' a red double decker bus driving down a street .'],
#              264683: [' a large airplane is on display in a hangar .'],
#              264686: [' a living room with a couch and a couch'],
#              133619: [' a fire truck is parked in front of a building .'],
#              133620: [' a man in a red jacket and a black jacket'],
#              526837: [' a skier is coming down the slope on a sunny day .'],
#              133622: [' a plate of food with meat and vegetables .'],
#              153343: [' a teddy bear sitting on a table with a teddy bear .'],
#              133629: [' a living room with a couch and a coffee table'],
#              133631: [' an elephant is standing in the dirt near a tree .'],
#              2562: [' a tennis player holding a tennis racket on a court .'],
#              133636: [' a parking meter with a meter on it'],
#              133645: [' a boat is docked on the water near a river .'],
#              264718: [' a street sign on a pole on a city street .'],
#              133648: [' a black and white photo of a baseball player'],
#              328110: [' a woman sitting on a bench in front of a building .'],
#              395801: [' a man riding a skateboard down a street .'],
#              264730: [' a clock tower with a clock on top of it .'],
#              2587: [' a banana is sitting on a plate next to a banana .'],
#              2592: [' a cup of coffee and a cup of coffee .'],
#              262576: [' a laptop computer sitting on top of a desk .'],
#              133667: [' a man is sitting on a couch with a laptop .'],
#              526892: [' a man is standing in a kitchen with a refrigerator .'],
#              87377: [' a cat sitting on top of a laptop computer .'],
#              133679: [' a living room with a couch and a television .'],
#              133680: [' a man riding a bike down a street .'],
#              264753: [' a train is parked on the tracks near a station .'],
#              2613: [' a man riding a wave on top of a surfboard .'],
#              395831: [' a person is preparing food in a kitchen .'],
#              526904: [' a group of people sitting at a table with a laptop .'],
#              133690: [' a woman is laying on a bed with a laptop .'],
#              2621: [' a red and white fire hydrant on a street .'],
#              401623: [' a bathroom with a toilet and a sink'],
#              264769: [' a person is cutting a piece of cake on a table .'],
#              133698: [' a pizza sitting on top of a metal pan .'],
#              395843: [' a person on a beach with a kite in the air'],
#              395849: [' a plane is sitting on the runway at the airport .'],
#              133707: [' a black cat sitting on top of a wooden bench .'],
#              2640: [' a train is on the tracks near a bridge .'],
#              264787: [' a cat is laying on a blanket on a blanket .'],
#              526933: [' a woman is sitting on a couch with a cell phone .'],
#              395865: [' a street sign on a pole on a street .'],
#              526940: [' a woman holding a cell phone in her hand .'],
#              393659: [' a bathroom with a sink and a mirror'],
#              264805: [' a bathroom with a sink and a mirror'],
#              526955: [' a woman is talking on her cell phone .'],
#              526956: [' a red umbrella is on a beach next to a river .'],
#              395890: [' a man and woman sitting in a room with a table .'],
#              264819: [' a snowboarder performing a jump off a ramp .'],
#              133750: [' a couple of animals that are standing in the grass .'],
#              306281: [' a close up of a plate of food on a table'],
#              2684: [' a group of zebras standing in a field next to a tree .'],
#              2685: [' a man is sitting on a bench in front of a laptop .'],
#              484551: [' a man is riding a surfboard in the water .'],
#              395903: [' a man is standing on a surfboard in the water .'],
#              395904: [' a man is preparing food in a kitchen .'],
#              2690: [' a boat is docked at the shore of a lake .'],
#              133778: [' a cow standing in a field with a cow .'],
#              264853: [' a man is playing tennis on a tennis court .'],
#              264855: [' a cat sitting on top of a wooden table next to a window .'],
#              395928: [' a bench sitting in the middle of a park .'],
#              527002: [' a man riding a wave on top of a surfboard .'],
#              502895: [' a train on a train track with a sky background'],
#              264870: [' a white refrigerator freezer sitting next to a white sink .'],
#              527022: [' a group of giraffes are standing in the grass .'],
#              527023: [' a group of people playing a game of tennis .'],
#              527025: [' a group of people standing around a table .'],
#              527029: [' a man is preparing food in a kitchen .'],
#              133819: [' a red double decker bus driving down a street .'],
#              133821: [' a bench with a tree on it and a tree'],
#              527038: [' a street sign on a pole on a city street .'],
#              527040: [' a table with a tray of food and a glass of wine'],
#              2753: [' a dog is sitting on a bench in the water .'],
#              133827: [' a city street with a traffic light on the side of the road .'],
#              2759: [' a bowl of soup and vegetables on a table .'],
#              395978: [' a group of people riding boards down a snow covered slope .'],
#              44151: [' a street sign on a sidewalk next to a tree .'],
#              2764: [' a group of people on a beach with a sail in the water .'],
#              264909: [' a black and white photo of a sheep in a field'],
#              527054: [' a woman is standing on a skateboard in the snow .'],
#              527060: [' a woman is cutting a cake with a knife .'],
#              264919: [' a woman holding a pink umbrella in her hands .'],
#              527064: [' a pizza sitting on top of a wooden table .'],
#              395997: [' a dog is sitting on a car dash by a window .'],
#              305609: [' a table topped with plates of food and a glass of wine .'],
#              133867: [' a man riding a skateboard down a street .'],
#              264940: [' a fire hydrant on a sidewalk next to a street .'],
#              133869: [' a woman walking down a street with a cell phone .'],
#              527086: [' a group of people sitting around a table with a cake on it .'],
#              133876: [' a man is sitting on a bed with his feet up .'],
#              527098: [' a boat is docked at a dock in the water .'],
#              264957: [' a black and white photo of a train on a train track'],
#              527102: [' a group of people standing around a table with food .'],
#              264961: [' a motorcycle is parked on a street in the city .'],
#              264962: [' a zebra standing in a field next to a tree .'],
#              264964: [' a toilet with a plunger on top of it .'],
#              2822: [' a person is standing in a field with a kite .'],
#              264968: [' a man is playing baseball on a field'],
#              264976: [' a white toilet sitting next to a white toilet .'],
#              396051: [' a plane is sitting on the runway at the airport'],
#              2839: [' a baby is sitting in a high chair eating a piece of food .'],
#              264992: [' a pile of oranges sitting on a table next to a pile of oranges .'],
#              415536: [' a bus driving down a street next to a tree .'],
#              133923: [' a street sign on a pole on a city street .'],
#              396068: [' a woman is standing in the street with a cell phone .'],
#              571847: [' a person holding a donut with a dog on it .'],
#              133927: [' a woman is playing tennis on a tennis court .'],
#              133928: [' a boat is floating on the water near a lake .'],
#              265001: [' a bird is perched on a tree branch .'],
#              265003: [' a dog is sitting on a grass covered field .'],
#              133933: [' a man and woman playing a game on a wii .'],
#              2867: [' a group of people standing on top of snow covered ground .'],
#              527163: [' a boat is docked at a dock in the water .'],
#              527164: [' a traffic light hanging above a street sign .'],
#              396094: [' a black cat is sitting in a bathroom sink .'],
#              2881: [' a train is traveling down the tracks near a forest .'],
#              2890: [' a group of people standing on top of snow covered ground .'],
#              133963: [' a man is sitting on a bench in front of a window .'],
#              133964: [' a group of people sitting on a bench in the water .'],
#              2894: [' a train is parked on the tracks near a station .'],
#              133969: [' a baseball player is swinging at a pitch .'],
#              21919: [' a young boy is playing baseball on a field'],
#              ...})

# %%
import pickle

# write a file
f1 = open("valid_result", "wb")
pickle.dump(valid_result, f1)
f1.close()

f2 = open("pred_result", "wb")
pickle.dump(pred_result, f2)
f2.close()

# %%
from bleu import Bleu
bleu_scorer = Bleu()

score, scores = bleu_scorer.compute_score(valid_result, pred_result)

# %%
def BLEU_score(gt_caption, sample_caption):
    """
    gt_caption: string, ground-truth caption
    sample_caption: string, your model's predicted caption
    Returns unigram BLEU score.
    """
    reference = [x for x in gt_caption.split(' ') 
                 if ('<end>' not in x and '<start>' not in x and '<unk>' not in x)]
    hypothesis = [x for x in sample_caption.split(' ') 
                  if ('<end>' not in x and '<start>' not in x and '<unk>' not in x)]
    BLEUscore = nltk.translate.bleu_score.sentence_bleu([reference], hypothesis, weights = [1])
    return BLEUscore

# %%
from nltk.translate.bleu_score import SmoothingFunction

# %%
def validate(val_loader, encoder, decoder, criterion, vocab, epoch, 
             total_step, start_step=1, start_loss=0.0, start_bleu=0.0):
    """Validate the model for one epoch using the provided parameters. 
    Return the epoch's average validation loss and Bleu-4 score."""

    # Switch to validation mode
    encoder.eval()
    decoder.eval()

    # Initialize smoothing function
    smoothing = SmoothingFunction()

    # Keep track of validation loss and Bleu-4 score
    total_loss = start_loss
    total_bleu_4 = start_bleu

    # Start time for every 100 steps
    start_val_time = time.time()

    # Disable gradient calculation because we are in inference mode
    with torch.no_grad():
        for i_step in range(start_step, total_step + 1):
            # Randomly sample a caption length, and sample indices with that length
            indices = val_loader.dataset.get_train_indices()
            # Create a batch sampler to retrieve a batch with the sampled indices
            new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
            val_loader.batch_sampler.sampler = new_sampler

            # Obtain the batch
            for batch in val_loader:
                images, captions = batch[0], batch[1]
                break 

            # Move to GPU if CUDA is available
            if torch.cuda.is_available():
                images = images.cuda()
                captions = captions.cuda()
            
            # Pass the inputs through the CNN-RNN model
            features = encoder(images)
            outputs = decoder(features, captions)

            # Calculate the total Bleu-4 score for the batch
            batch_bleu_4 = 0.0
            # Iterate over outputs. Note: outputs[i] is a caption in the batch
            # outputs[i, j, k] contains the model's predicted score i.e. how 
            # likely the j-th token in the i-th caption in the batch is the 
            # k-th token in the vocabulary.
            for i in range(len(outputs)):
                predicted_ids = []
                for scores in outputs[i]:
                    # Find the index of the token that has the max score
                    predicted_ids.append(scores.argmax().item())
                # Convert word ids to actual words
                predicted_word_list = word_list(predicted_ids, vocab)
                caption_word_list = word_list(captions[i].numpy(), vocab)
                # Calculate Bleu-4 score and append it to the batch_bleu_4 list
                batch_bleu_4 += sentence_bleu([caption_word_list], 
                                               predicted_word_list, 
                                               smoothing_function=smoothing.method1)
            total_bleu_4 += batch_bleu_4 / len(outputs)

            # Calculate the batch loss
            loss = criterion(outputs.view(-1, len(vocab)), captions.view(-1))
            total_loss += loss.item()
            
            # Get validation statistics
            stats = "Epoch %d, Val step [%d/%d], %ds, Loss: %.4f, Perplexity: %5.4f, Bleu-4: %.4f" \
                    % (epoch, i_step, total_step, time.time() - start_val_time,
                       loss.item(), np.exp(loss.item()), batch_bleu_4 / len(outputs))

            # Print validation statistics (on same line)
            print("\r" + stats, end="")
            sys.stdout.flush()

            # Print validation statistics (on different line) and reset time
            if i_step % PRINT_EVERY == 0:
                print("\r" + stats)
                filename = os.path.join("./models", "val-model-{}{}.pkl".format(epoch, i_step))
                save_val_checkpoint(filename, encoder, decoder, total_loss, total_bleu_4, epoch, i_step)
                start_val_time = time.time()
                
        return total_loss / total_step, total_bleu_4 / total_step

# %%
from data_loader import get_loader

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Build data loader.
val_loader = get_loader(transform=transform_train,
                         mode='val',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold)
# Out:
# start
# Vocabulary successfully loaded from vocab.pkl file!

# %%
validate(val_loader, encoder, decoder, criterion, val_loader.dataset.vocab, epoch, 
             total_step, start_step=1, start_loss=0.0, start_bleu=0.0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-74356bf34e94> in <module>
#       1 validate(val_loader, encoder, decoder, criterion, val_loader.dataset.vocab, epoch,
# ----> 2              total_step, start_step=1, start_loss=0.0, start_bleu=0.0)
#
# <ipython-input-41-5de19e1d8d07> in validate(val_loader, encoder, decoder, criterion, vocab, epoch, total_step, start_step, start_loss, start_bleu)
#      22         for i_step in range(start_step, total_step + 1):
#      23             # Randomly sample a caption length, and sample indices with that length
# ---> 24             indices = val_loader.dataset.get_train_indices()
#      25             # Create a batch sampler to retrieve a batch with the sampled indices
#      26             new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
#
# ~/imageCap/CVND---Image-Captioning-Project/data_loader.py in get_train_indices(self)
#     147
#     148     def get_train_indices(self):
# --> 149         sel_length = np.random.choice(self.caption_lengths)
#     150         all_indices = np.where([self.caption_lengths[i] == sel_length for i in np.arange(len(self.caption_lengths))])[0]
#     151         indices = list(np.random.choice(all_indices, size=self.batch_size))
#
# AttributeError: 'CoCoDataset' object has no attribute 'caption_lengths'
